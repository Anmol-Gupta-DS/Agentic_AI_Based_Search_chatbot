# %% [markdown]
# # Banking Agentic AI Use Case Discovery
#
# This notebook is the working space for a notebook-first delivery style. We will explore the problem, define personas, and capture the MVP scope here before promoting validated logic into deployment-ready `.py` modules.

# %% [markdown]
# ## Working agreement
# - Prototype and iterate in notebooks.
# - Keep assumptions explicit and reviewable.
# - Convert stable logic into Python modules under `src/` for deployment.

# %%
from pathlib import Path
import sys

project_root = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
src_path = project_root / 'src'
if str(src_path) not in sys.path:
    sys.path.append(str(src_path))

from banking_assistant import (
    BANKING_ASSISTANT_BLUEPRINT,
    get_dataset_dir,
    summarize_available_datasets,
    summarize_mvp_scope,
)

# %%
BANKING_ASSISTANT_BLUEPRINT.to_dict()

# %%
summarize_mvp_scope()

# %% [markdown]
# ## Next notebook steps
# 1. Add sample or synthetic banking service data for exploratory analysis.
# 2. Evaluate which user journeys should be prioritized for the MVP.
# 3. Convert validated logic, prompts, and retrieval utilities into `src/` modules for deployment.

# %% [markdown]
# ## Local sample dataset inventory
# Store your JSON or CSV sample data inside the repository-local `dataset/` folder so analysis stays reproducible and self-contained.

# %%
get_dataset_dir(create=True)

# %%
summarize_available_datasets()
